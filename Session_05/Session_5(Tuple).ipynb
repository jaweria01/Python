# %% [markdown]
# <a href="https://colab.research.google.com/github/jaweria01/Python/blob/main/Session_05/Session_5(Tuple).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tuples**
# A tuple in Python is similar to a list. The difference between the two is that we cannot change the elements of a tuple once it is assigned whereas we can change the elements of a list.
#
# In short, a tuple is an immutable list. A tuple can not be changed in any way once it is created.
#
# ***Characterstics***
#
# Ordered
#
# Unchangeble
#
# Allows duplicate

# %% [markdown]
# ### **Plan of attack**
#
# Creating a Tuple
#
# Accessing items
#
# Editing items
#
# Adding items
#
# Deleting items
#
# Operations on Tuples
#
# Tuple Functions

# %%
# empty
t1 = ()
print(t1)
# create a tuple with a single item ", " a comma is necessary for single item tuple
t2 = ('hello',)
print(t2)
print(type(t2))
# homo
t3 = (1,2,3,4)
print(t3)
# hetro
t4 = (1,2.5,True,[1,2,3])
print(t4)
# tuple with in a tuple just like 2 D list
t5 = (1,2,3,(4,5))
print(t5)
# using type conversion
t6 = tuple('hello')
print(t6)

# %% [markdown]
# ### **Accessing Items**
# Indexing
#
# Slicing

# %%
a = (1,2,3,4)
print(a)
# +ve indexing
print(a[0])
# -ve indexing
print(a[-1])
# Out:
# (1, 2, 3, 4)
# 1
# 4

# %%
# Slicing
# +ve slicing
b = (1,2,3,4,5)
b[0:3:]
# Out:
# (1, 2, 3)

# %%
# In +ve slicing , left always small except , when we want to -ve step or reverse the numbers
b = (1,2,3,4,5)
b[3:0:1]
# Out:
# ()

# %%
b = (1,2,3,4,5)
b[0:3:1]
# Out:
# (1, 2, 3)

# %%
b = (1,2,3,4,5)
b[3:0:-1]
# Out:
# (4, 3, 2)

# %%
# ************In +ve slicing we can not put -ve step when left is small ************************
b = (1,2,3,4,5)
b[0:3:-2]
# Out:
# ()

# %%
b = (1,2,3,4,5)
b[0:3:-1]
# Out:
# ()

# %%
b = (1,2,3,4,5)
b[3:0:-1]
# Out:
# (4, 3, 2)

# %%
b = (1,2,3,4,5)
b[3:0:1]
# Out:
# ()

# %%
b = (1,2,3,4,5)
b[:2]
# Out:
# (1, 2)

# %%
b = (1,2,3,4,5)
b[2]
# Out:
# 3

# %%
b = (1,2,3,4,5)
b[::]
# Out:
# (1, 2, 3, 4, 5)

# %%
# I want to print 2 and 4 by +ve slicing
b = (1,2,3,4,5)
b[1:6:2]
# Out:
# (2, 4)

# %%
# -ve slicing
# I want to print 2 and 4 by -ve slicing
b = (1,2,3,4,5)
b[-4:-1:2]
# Out:
# (2, 4)

# %%
b = (1,2,3,4,5)
b[-3:-1]

# %%
# To reverse
b = (1,2,3,4,5)
b[::-1]
# Out:
# (5, 4, 3, 2, 1)

# %%
# at left always should be greater, if you want reverse in -ve
b = (1,2,3,4,5)
b[-1:-4:-1]
# Out:
# (5, 4, 3)

# %%
b = (1,2,3,4,5)
b[-3::-1]
# Out:
# (3, 2, 1)

# %%
# *************** in -ve Indexing left should be greater always *****************
b = (1,2,3,4,5)
b[-5:-3:-1]
# Out:
# ()

# %%
b = (1,2,3,4,5)
b[-3:-5:-1]
# Out:
# (3, 2)

# %%
b = (1,2,3,4,5)
b[-3:-5:1]
# Out:
# ()

# %%
# ****** we just put +ve step in negative indexing , when left is less ******
b = (1,2,3,4,5)
b[-5:-3:1]
# Out:
# (1, 2)

# %%
# Extracting item from 2D tuple
t = (1,2,3,4,(5,6))
t[-1][0]
# Out:
# 5

# %% [markdown]
# ## **Editing items**

# %%
# want to add 100 at 0 index
# print(t3)
# t3[0] = 100
# immutable just like strings

# %% [markdown]
# ## **Adding items**

# %%
print(t3)
# not possible

# %% [markdown]
# ## **Deleting Items**

# %%
t = (1,2,3)
print(t)
del t
#print(t3)
# Out:
# (1, 2, 3)

# %% [markdown]
# ## **Operations on Tuples**

# %%
# Operator
# Membership
# Loops /iteration

# %%
# Operator
t1 = (1,2,3,4)
t2 = (5,6,7,8)
t1 +t2
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)

# %%
# *
t1 = (1,2,3,4)
t2 = (5,6,7,8)

t1 * 2
# Out:
# (1, 2, 3, 4, 1, 2, 3, 4)

# %%
# Membership
t = (1,2,3)
1 in t
4 in t
# Out:
# False

# %%
# Loop
t = (1,2,3,4,5,5,6,6,8,9)
for i in t:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 5
# 6
# 6
# 8
# 9

# %% [markdown]
# ## **Tuple Functions**

# %%
# # len/sum/min/max/sorted
# len(t)
# sum(t)
# min(t)
# max(t)
# sorted
# count

# %%
t = (1,2,3,4)
len(t)
# Out:
# 4

# %%
t = (1,2,3,4)
sum(t)
# Out:
# 10

# %%
t = (1,2,3)
min(t)
# Out:
# 1

# %%
t = (1,2,3)
max(t)
# Out:
# 3

# %%
# Result always in list
t = (10,11,12,13,14)
sorted(t,reverse=True)
# Out:
# [14, 13, 12, 11, 10]

# %%
# count

t = (1,2,3,4,5)

t.count(50)
# Out:
# 0

# %%
t = (1,2,3,4,5)

t.count(5)
# Out:
# 1

# %%
# index
t = (1,2,3,4,5)
#t.index(50)
t.index(4)
# Out:
# 3

# %% [markdown]
# ## **Difference between Lists and Tuples**
#
# Syntax
#
# Mutability
#
# Speed
#
# Memory
#
# Built in functionality
#
# Error prone
#
# Usability

# %%
# syntax of both are different from each other: (tuple) [list]
# List are mutable but tuple are not
# Speed of tuple are more. they are faster
# Tuples take less space in memory
# List has more functions as compared to tuple
# Lists are more error prone due to mutability
# In applications where user did nt do any changes then you will use tuple, whereas where user will do more changes then you will use list like to do list

# %%
# tuples are faster
import time

L = list(range(100000000))
T = tuple(range(100000000))

start = time.time()
for i in L:
  i*5
print('List time',time.time()-start)

start = time.time()
for i in T:
  i*5
print('Tuple time',time.time()-start)
# Out:
# List time 9.703708410263062
# Tuple time 9.690252780914307

# %%
# tuple take less memory
import sys

L = list(range(1000))
T = tuple(range(1000))

print('List size',sys.getsizeof(L))
print('Tuple size',sys.getsizeof(T))
# Out:
# List size 8056
# Tuple size 8040

# %%
# List have more chances of error due to mutability
a = [1,2,3]
b = a

a.append(4)
print(a)
print(b)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
# tuples are not error prone due to immutable
# tuple have no method of apppend
a = (1,2,3)
b = a

a = a + (4,)
print(a)
print(b)
# Out:
# (1, 2, 3, 4)
# (1, 2, 3)

# %% [markdown]
# ## **Tuple Unpacking**

# %%
# tuple unpacking
a,b,c = (1,2,3)
print(a,b,c)

# %%
# a,b = (1,2,3)
# print(a,b)

# %%
# Values swapping
# no need of third variable
a = 1
b = 2
a,b = b,a

print(a,b)

# %%
# Tupple unpacking
a,b,*others = (1,2,3,4)
print(a,b)
print(others)
# Out:
# 1 2
# [3, 4]

# %% [markdown]
# ## **Zip Tupple**

# %%
Zip :
# Zip function operate on two iterables item by item

# %%
a = (1,2,3,4)
b = (5,6,7,8)
# make a zip object
zip(a,b)

# %%
# To see the zip object , convert it into list or tuple
# zipping tuples
a = (1,2,3,4)
b = (5,6,7,8)
# tuple of tuples? 2D tuple
tuple(zip(a,b))
# Out:
# ((1, 5), (2, 6), (3, 7), (4, 8))

# %%
# list tuples
a = (1,2,3,4)
b = (5,6,7,8)
# you will get  list of tuple
list(zip(a,b))
# Out:
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %% [markdown]
# ## ***Tuple Comprehension***

# %%
# just like in list

(i for i in range(0,10))
# Out:
# <generator object <genexpr> at 0x78ee68c05af0>

# %%
#
t = (1,2,3,4,56,9)
tc = (i for i in t)
print(tc)
# Out:
# <generator object <genexpr> at 0x78ee68c06110>

# %%
# **************** all read operations can be tuples ************************
# ************** all write operations can be possible in list **********************
